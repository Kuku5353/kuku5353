# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuku5353/kuku5353/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = '/content/heights.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    height  weight
# 0     198      98
# 1     170      77
# 2     170      70
# 3     198      90
# 4     170      71

# %%
x = df[ 'height' ]
y = df[ 'weight' ]
plt.plot(x, y, 'o')
plt.xlabel ('height')
plt.ylabel ('weight')
# Out:
# Text(0, 0.5, 'weight')

# %%
line_fitter = LinearRegression()
line_fitter.fit(x.values.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
line_fitter.coef_
# Out:
# array([0.43271112])

# %%
line_fitter.intercept_
# Out:
# np.float64(0.9251942100262909)

# %%
plt.plot(x, y, 'o')
plt.plot(x, line_fitter.predict(x.values.reshape(-1,1)))
plt.show()

# %%
line_fitter.predict([[172]])
# Out:
# array([75.35150618])
